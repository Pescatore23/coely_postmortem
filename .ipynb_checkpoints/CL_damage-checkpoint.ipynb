# %% [markdown]
# # Analysis of extracted catalyst layer

# %%
import skimage #scikit-image version 0.22.0
import os
import matplotlib.pyplot as plt #matplotlib version 3.7.3
from matplotlib import cm #matplotlib version 3.7.3
from matplotlib.colors import Normalize #matplotlib version 3.7.3
from mpl_toolkits.axes_grid1 import make_axes_locatable #matplotlib version 3.7.3
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar #matplotlib version 3.7.3
import matplotlib.font_manager as fm #matplotlib version 3.7.3
import numpy as np #numpy version 1.26.4
from datetime import datetime
import json
import pandas as pd #pandas version 2.2.1
import skimage.io #scikit-image version 0.22.0

# workaround until galvani pip module can handle  EClab v11.5
cwd = os.getcwd()
os.chdir('/mpc/homes/fische_r/lib/python_playground') #path where BioLogic.py sits
import BioLogic 
os.chdir(cwd)

# %%
toppath = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem'

# %% [markdown]
# ### show all data

# %%
series = ['A', 'B', 'C', 'Z', 'D', 'E']

def get_series_sample(series):
    series_path = os.path.join(toppath, series+'_series')
    folders = os.listdir(series_path)
    samples = []
    for sample in folders:
        samples.append(sample.split('_')[-1])
    paths = []
    for sample in samples:
        if series == 'Z' and sample in ['1', '2', '6']: continue
        sample_path = os.path.join(toppath, series+'_series', series+'_'+sample)
    
        files = os.listdir(sample_path)
        stages = []
        for file in files:
            splitfile = file.split('_')
            if splitfile[-1] == 'rotcrop.tif':
                stage = ''.join([i+'_' for i in splitfile[2:-1]])
                stages.append(stage)
        for stage in stages:
            imroot = series+'_'+sample+'_'+stage
            outpath = os.path.join(sample_path, 'CL_extraction')
            path = os.path.join(outpath, imroot+'_extracted_CL.tif')
            # print(path)
            paths.append((series, sample, stage[:-1], path))
    return paths

image_paths = get_series_sample('A') + get_series_sample('B') + get_series_sample('C') + get_series_sample('Z')+ get_series_sample('D')+ get_series_sample('E')

# %%
## put images into dict
image_dict = {}
image_dict['A'] = {}
image_dict['B'] = {}
image_dict['C'] = {}
image_dict['Z'] = {}
image_dict['D'] = {}
image_dict['E'] = {}

images = []
meds = []
for impath in image_paths:
    print(impath)
    ser = impath[0]
    sample = impath[1]
    if ser+'_'+sample == 'Z_7':
        image_paths.remove(impath)
        continue
    image_dict[ser][sample] = {}
    im = skimage.io.imread(impath[-1])
    images.append(im)

for (impath, im) in zip(image_paths, images):
    ser = impath[0]
    sample = impath[1]
    stage = impath[2]
    med = np.median(im[100:1100,50:550])
    diff = med -0.8
    image_dict[ser][sample][stage] = {'im': im, 'norm_im': im-diff}
    meds.append(med)
    

# flag = True
# for k in range(len(images)):
#     im = images[k]
#     med = meds[k]
#     #normalize im
#     diff = med - 0.8
#     normim = im - diff
# Out:
# ('A', '13', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_13/CL_extraction/A_13_postop_1__extracted_CL.tif')
# ('A', '13', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_13/CL_extraction/A_13_preop__extracted_CL.tif')
# ('A', '3', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_3/CL_extraction/A_3_postop_1__extracted_CL.tif')
# ('A', '3', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_3/CL_extraction/A_3_postop_2__extracted_CL.tif')
# ('A', '3', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_3/CL_extraction/A_3_preop__extracted_CL.tif')
# ('A', '9', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_9/CL_extraction/A_9_postop_1__extracted_CL.tif')
# ('A', '9', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_9/CL_extraction/A_9_preop__extracted_CL.tif')
# ('A', '11', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_11/CL_extraction/A_11_postop_1__extracted_CL.tif')
# ('A', '11', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_11/CL_extraction/A_11_preop__extracted_CL.tif')
# ('A', '4', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_4/CL_extraction/A_4_preop__extracted_CL.tif')
# ('A', '4', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_4/CL_extraction/A_4_postop_2__extracted_CL.tif')
# ('A', '4', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_4/CL_extraction/A_4_postop_1__extracted_CL.tif')
# ('A', '6', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_6/CL_extraction/A_6_postop_1__extracted_CL.tif')
# ('A', '6', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_6/CL_extraction/A_6_preop__extracted_CL.tif')
# ('A', '12', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_12/CL_extraction/A_12_postop_2__extracted_CL.tif')
# ('A', '12', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_12/CL_extraction/A_12_preop__extracted_CL.tif')
# ('A', '12', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_12/CL_extraction/A_12_postop_1__extracted_CL.tif')
# ('B', '1', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_1/CL_extraction/B_1_postop_1__extracted_CL.tif')
# ('B', '1', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_1/CL_extraction/B_1_preop__extracted_CL.tif')
# ('B', '1', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_1/CL_extraction/B_1_postop_2__extracted_CL.tif')
# ('B', '5', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_5/CL_extraction/B_5_preop__extracted_CL.tif')
# ('B', '5', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_5/CL_extraction/B_5_postop_1__extracted_CL.tif')
# ('B', '4', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_4/CL_extraction/B_4_preop__extracted_CL.tif')
# ('B', '4', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_4/CL_extraction/B_4_postop_1__extracted_CL.tif')
# ('B', '2', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_2/CL_extraction/B_2_preop__extracted_CL.tif')
# ('B', '2', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_2/CL_extraction/B_2_postop_1__extracted_CL.tif')
# ('B', '2', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_2/CL_extraction/B_2_postop_2__extracted_CL.tif')
# ('B', '6', 'wet_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_6/CL_extraction/B_6_wet_2__extracted_CL.tif')
# ('B', '6', 'wet_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_6/CL_extraction/B_6_wet_1__extracted_CL.tif')
# ('B', '6', 'dry', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_6/CL_extraction/B_6_dry__extracted_CL.tif')
# ('B', '6', 'dry_40C', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_6/CL_extraction/B_6_dry_40C__extracted_CL.tif')
# ('C', '4', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_4/CL_extraction/C_4_postop_1__extracted_CL.tif')
# ('C', '4', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_4/CL_extraction/C_4_postop_2__extracted_CL.tif')
# ('C', '4', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_4/CL_extraction/C_4_preop__extracted_CL.tif')
# ('C', '3', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_3/CL_extraction/C_3_postop_1__extracted_CL.tif')
# ('C', '3', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_3/CL_extraction/C_3_preop__extracted_CL.tif')
# ('C', '5', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_5/CL_extraction/C_5_preop__extracted_CL.tif')
# ('C', '5', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_5/CL_extraction/C_5_postop_1__extracted_CL.tif')
# ('C', '1', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_1/CL_extraction/C_1_preop__extracted_CL.tif')
# ('C', '1', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_1/CL_extraction/C_1_postop_2__extracted_CL.tif')
# ('C', '1', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_1/CL_extraction/C_1_postop_1__extracted_CL.tif')
# ('C', '2', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_2/CL_extraction/C_2_preop__extracted_CL.tif')
# ('C', '2', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_2/CL_extraction/C_2_postop_1__extracted_CL.tif')
# ('C', '2', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_2/CL_extraction/C_2_postop_2__extracted_CL.tif')
# ('Z', '3', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/Z_series/Z_3/CL_extraction/Z_3_postop_1__extracted_CL.tif')
# ('Z', '3', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/Z_series/Z_3/CL_extraction/Z_3_preop__extracted_CL.tif')
# ('Z', '4', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/Z_series/Z_4/CL_extraction/Z_4_postop_1__extracted_CL.tif')
# ('Z', '4', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/Z_series/Z_4/CL_extraction/Z_4_postop_2__extracted_CL.tif')
# ('Z', '4', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/Z_series/Z_4/CL_extraction/Z_4_preop__extracted_CL.tif')
# ('Z', '7', 'dry', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/Z_series/Z_7/CL_extraction/Z_7_dry__extracted_CL.tif')
# ('D', '1', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/D_series/D_1/CL_extraction/D_1_preop__extracted_CL.tif')
# ('D', '1', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/D_series/D_1/CL_extraction/D_1_postop_1__extracted_CL.tif')
# ('D', '2', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/D_series/D_2/CL_extraction/D_2_postop_1__extracted_CL.tif')
# ('D', '2', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/D_series/D_2/CL_extraction/D_2_preop__extracted_CL.tif')
# ('D', '2', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/D_series/D_2/CL_extraction/D_2_postop_2__extracted_CL.tif')
# ('E', '3', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/E_series/E_3/CL_extraction/E_3_postop_2__extracted_CL.tif')
# ('E', '3', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/E_series/E_3/CL_extraction/E_3_preop__extracted_CL.tif')
# ('E', '3', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/E_series/E_3/CL_extraction/E_3_postop_1__extracted_CL.tif')
# ('E', '4', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/E_series/E_4/CL_extraction/E_4_postop_1__extracted_CL.tif')
# ('E', '4', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/E_series/E_4/CL_extraction/E_4_preop__extracted_CL.tif')
# ('E', '4', 'postop_2', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/E_series/E_4/CL_extraction/E_4_postop_2__extracted_CL.tif')
# ('E', '1', 'preop', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/E_series/E_1/CL_extraction/E_1_preop__extracted_CL.tif')
# ('E', '1', 'postop_1', '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/E_series/E_1/CL_extraction/E_1_postop_1__extracted_CL.tif')

# %%
bins = np.arange(0,2, 1.5/100)
meds = []
for k in range(len(images)):
    im = images[k]
    impath = image_paths[k]
    ser = impath[0]
    sample = impath[1]
    # if not ser == 'C' or not sample == '2': continue
    med = np.median(im[100:1100,50:550])
    meds.append(med)
    hist = np.histogram(im[100:1100,50:550].flatten(), bins=bins)
    diff = med-0.8
    diff = 0
    if ser == 'Z' and sample == '4': continue
    if ser == 'C' and sample == '4' and impath[2] == 'preop': continue
    plt.plot(hist[1][1:]-diff, hist[0], label = impath[2])
plt.xlabel('grayvalue')
plt.ylabel('counts')
# plt.legend()
# Out:
# Text(0, 0.5, 'counts')

# %%
images
# Out:
# [array([[0.64239573, 0.9652224 , 1.0121672 , ..., 0.7454195 , 0.5332843 ,
#          0.64037514],
#         [0.6421214 , 0.96920097, 1.0105205 , ..., 0.7372723 , 0.5838794 ,
#          0.61315084],
#         [0.67492586, 0.9456137 , 1.0558866 , ..., 0.61857784, 0.5187771 ,
#          0.63018495],
#         ...,
#         [0.40310845, 0.38306907, 0.25135925, ..., 0.6207556 , 0.5358708 ,
#          0.44772348],
#         [0.42631614, 0.36752212, 0.27575943, ..., 0.6050113 , 0.57454246,
#          0.5416926 ],
#         [0.3462213 , 0.35980147, 0.3239616 , ..., 0.62126917, 0.5925382 ,
#          0.6100984 ]], dtype=float32),
#  array([[0.9258699 , 0.9410751 , 0.8333551 , ..., 0.91764843, 0.974694  ,
#          0.89469385],
#         [0.9800136 , 0.796943  , 0.7489703 , ..., 0.9121049 , 1.0191666 ,
#          0.9172297 ],
#         [0.7917268 , 0.77211094, 0.62070733, ..., 0.9660903 , 1.0872128 ,
#          1.0504173 ],
#         ...,
#         [0.20503192, 0.25906694, 0.22149171, ..., 0.92454964, 0.8573583 ,
#          0.86740404],
#         [0.16149963, 0.2062711 , 0.17817982, ..., 0.9485379 , 0.86970717,
#          0.81845754],
#         [0.14950345, 0.18079425, 0.17226833, ..., 0.8549723 , 0.7893739 ,
#          0.6783509 ]], dtype=float32),
#  array([[1.1823163 , 0.64587873, 0.40918306, ..., 0.96400005, 1.0399067 ,
#          1.0081692 ],
#         [0.84150016, 0.52716595, 0.5141315 , ..., 0.9485831 , 0.98867   ,
#          0.91878456],
#         [0.56285393, 0.5422356 , 0.78396744, ..., 0.9265605 , 0.91969824,
#          0.81073326],
#         ...,
#         [1.3932498 , 1.2620392 , 1.1189328 , ..., 1.0269281 , 0.8476827 ,
#          0.7501548 ],
#         [1.417963  , 1.3923486 , 1.2078317 , ..., 0.9316087 , 0.81827873,
#          0.6382374 ],
#         [1.275998  , 1.3298955 , 1.1923097 , ..., 0.8871153 , 0.92209005,
#          0.9067626 ]], dtype=float32),
#  array([[1.2732651 , 1.2674894 , 1.2909065 , ..., 0.9197873 , 0.9271401 ,
#          0.9829084 ],
#         [1.0513194 , 1.1569792 , 1.2263404 , ..., 0.90702236, 1.0408508 ,
#          1.2351885 ],
#         [1.2097068 , 1.0940976 , 1.2615217 , ..., 0.9986299 , 0.9450054 ,
#          1.0846275 ],
#         ...,
#         [0.8033139 , 0.6527015 , 0.5189729 , ..., 1.0758789 , 1.1441265 ,
#          1.1338618 ],
#         [0.8394944 , 0.74953884, 0.5643019 , ..., 1.1325028 , 1.1056479 ,
#          1.0174342 ],
#         [1.0690048 , 0.886558  , 0.6395253 , ..., 0.96543944, 1.0330584 ,
#          0.9712565 ]], dtype=float32),
#  array([[1.1589308 , 1.122975  , 0.97978026, ..., 1.3176286 , 1.3663083 ,
#          1.3402295 ],
#         [1.1964225 , 1.060631  , 0.78385204, ..., 1.0566046 , 1.2708431 ,
#          1.4882976 ],
#         [1.0396787 , 0.88578296, 0.7564793 , ..., 0.9728582 , 1.2963264 ,
#          1.4623065 ],
#         ...,
#         [1.057022  , 1.0862558 , 1.0411808 , ..., 0.67342013, 0.58256084,
#          0.4157466 ],
#         [1.0760609 , 1.1120455 , 1.0359883 , ..., 0.71426374, 0.58569676,
#          0.37949163],
#         [1.1005074 , 1.0978949 , 1.0298954 , ..., 0.7303096 , 0.61408025,
#          0.5223002 ]], dtype=float32),
#  array([[0.8672175 , 0.69462305, 0.6379316 , ..., 0.30037135, 0.4690404 ,
#          0.5523518 ],
#         [0.72983956, 0.68986183, 0.8189381 , ..., 0.3953208 , 0.4788979 ,
#          0.553662  ],
#         [0.73047817, 0.88507956, 1.0040998 , ..., 0.33906427, 0.49658915,
#          0.60767025],
#         ...,
#         [1.1174582 , 1.0639149 , 0.93802434, ..., 0.77283084, 0.803657  ,
#          0.79543614],
#         [1.1044431 , 1.1574032 , 1.2611884 , ..., 0.79323745, 0.77979904,
#          0.770593  ],
#         [1.3035995 , 1.45707   , 1.4450489 , ..., 0.7943967 , 0.8599094 ,
#          0.82074296]], dtype=float32),
#  array([[1.0779645e+00, 1.0931629e+00, 1.0530913e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [9.6338248e-01, 1.0135046e+00, 1.1400446e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [8.3541238e-01, 9.1818219e-01, 1.0935290e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         ...,
#         [1.3490080e+00, 9.3873060e-01, 7.8836232e-01, ..., 0.0000000e+00,
#          0.0000000e+00, 3.1694427e-08],
#         [1.2572247e+00, 7.9067314e-01, 6.1911744e-01, ..., 0.0000000e+00,
#          0.0000000e+00, 5.9048435e-08],
#         [9.7437537e-01, 6.4693362e-01, 7.4679768e-01, ..., 0.0000000e+00,
#          0.0000000e+00, 8.2282035e-08]], dtype=float32),
#  array([[0.82513815, 0.6328571 , 0.59929335, ..., 0.5282353 , 0.53779596,
#          0.38873154],
#         [0.7945807 , 0.65540946, 0.5575788 , ..., 0.4709958 , 0.5405655 ,
#          0.3603549 ],
#         [0.7814858 , 0.71001506, 0.6540745 , ..., 0.41000292, 0.42524475,
#          0.2910908 ],
#         ...,
#         [0.20343858, 0.26410785, 0.22447264, ..., 0.21795495, 0.2035424 ,
#          0.18775754],
#         [0.21452443, 0.26088375, 0.22653948, ..., 0.26307306, 0.22213677,
#          0.21661247],
#         [0.22992365, 0.29132968, 0.24447986, ..., 0.22169963, 0.22342117,
#          0.18056265]], dtype=float32),
#  array([[0.636007  , 0.59014446, 0.5278769 , ..., 0.24601503, 0.22578879,
#          0.26674208],
#         [0.63777304, 0.5440839 , 0.5351846 , ..., 0.21730973, 0.23254797,
#          0.31512156],
#         [0.63213795, 0.57512563, 0.60123634, ..., 0.26286626, 0.24837072,
#          0.29771435],
#         ...,
#         [0.2071359 , 0.16643043, 0.16425537, ..., 0.23140895, 0.20027086,
#          0.24222305],
#         [0.14985466, 0.14837173, 0.18532354, ..., 0.19229868, 0.19317473,
#          0.20639062],
#         [0.16997035, 0.12864225, 0.14276727, ..., 0.20058753, 0.17866543,
#          0.22367351]], dtype=float32),
#  array([[1.4153905 , 0.9387654 , 0.69804007, ..., 0.32004175, 0.34467417,
#          0.45333374],
#         [1.41347   , 0.90993494, 0.6818027 , ..., 0.40655327, 0.3972815 ,
#          0.44185817],
#         [1.3438406 , 0.7745404 , 0.7300904 , ..., 0.49846846, 0.4456857 ,
#          0.48928827],
#         ...,
#         [0.7040019 , 0.6524048 , 0.73670936, ..., 0.92879564, 0.9416626 ,
#          0.99447703],
#         [0.67955667, 0.6649683 , 0.6341995 , ..., 0.90992516, 0.9577551 ,
#          0.9425647 ],
#         [0.7977917 , 0.7311675 , 0.58755076, ..., 0.89557433, 0.9269346 ,
#          0.9322598 ]], dtype=float32),
#  array([[1.2781012 , 1.0623633 , 1.0050228 , ..., 0.71592426, 0.8194707 ,
#          0.85907525],
#         [1.1246724 , 0.9554288 , 0.9189061 , ..., 0.7439747 , 0.79989755,
#          0.91974914],
#         [1.1401904 , 0.98100746, 0.949001  , ..., 0.76596475, 0.7343557 ,
#          0.91916984],
#         ...,
#         [0.95154554, 0.919528  , 0.98137474, ..., 0.        , 0.        ,
#          0.        ],
#         [1.0060304 , 1.1389577 , 1.1870627 , ..., 0.        , 0.        ,
#          0.        ],
#         [1.1751964 , 1.3584198 , 1.325267  , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.5843129 , 1.4475216 , 1.3714921 , ..., 0.567104  , 0.5481708 ,
#          0.77898645],
#         [1.3487586 , 1.2141747 , 1.106649  , ..., 0.646262  , 0.60441995,
#          0.77567226],
#         [1.0716333 , 0.9967355 , 0.9164522 , ..., 0.6989539 , 0.633267  ,
#          0.7124446 ],
#         ...,
#         [1.2138438 , 1.1194228 , 1.0142597 , ..., 0.        , 0.        ,
#          0.        ],
#         [1.3577343 , 1.2661233 , 1.0516942 , ..., 0.        , 0.        ,
#          0.        ],
#         [1.3383381 , 1.2186885 , 1.0972733 , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  array([[0.7668399 , 0.8307291 , 0.8225131 , ..., 0.40401664, 0.3181207 ,
#          0.29391548],
#         [0.6510297 , 0.78146464, 0.8874539 , ..., 0.37845692, 0.37931246,
#          0.29903352],
#         [0.5018514 , 0.66927785, 0.8812147 , ..., 0.37381113, 0.38837922,
#          0.33773062],
#         ...,
#         [0.49091247, 0.4302179 , 0.46069685, ..., 0.5462074 , 0.00252246,
#          0.        ],
#         [0.45489666, 0.4238601 , 0.5004408 , ..., 0.53441584, 0.00249902,
#          0.        ],
#         [0.40779215, 0.4545426 , 0.5028488 , ..., 0.58554053, 0.00309882,
#          0.        ]], dtype=float32),
#  array([[2.7760583e-05, 3.2523155e-04, 1.3467916e+00, ..., 3.3883771e-01,
#          3.0142671e-01, 3.0175892e-01],
#         [5.8977661e-05, 7.1942178e-04, 1.3809819e+00, ..., 3.1357294e-01,
#          2.5974140e-01, 2.9769522e-01],
#         [6.3823165e-05, 7.4733916e-04, 1.4016070e+00, ..., 2.2615121e-01,
#          2.8012240e-01, 2.7135187e-01],
#         ...,
#         [0.0000000e+00, 0.0000000e+00, 9.2052341e-01, ..., 1.0966992e+00,
#          1.1101198e+00, 1.1000469e+00],
#         [0.0000000e+00, 0.0000000e+00, 1.0255030e+00, ..., 1.1332918e+00,
#          1.2310822e+00, 1.1573999e+00],
#         [0.0000000e+00, 0.0000000e+00, 1.0721716e+00, ..., 1.1702367e+00,
#          1.1328825e+00, 1.0657079e+00]], dtype=float32),
#  array([[0.19695207, 0.1795906 , 0.19203472, ..., 0.3316216 , 0.4126017 ,
#          0.35792863],
#         [0.18931842, 0.19719616, 0.22510856, ..., 0.40821868, 0.41993436,
#          0.37534904],
#         [0.22426842, 0.19360371, 0.20884998, ..., 0.49374878, 0.4210745 ,
#          0.35263047],
#         ...,
#         [0.49268532, 0.3953426 , 0.35312697, ..., 0.86536855, 0.8045396 ,
#          0.8159512 ],
#         [0.41632107, 0.35779688, 0.34119537, ..., 0.866433  , 0.78686816,
#          0.72891676],
#         [0.34807488, 0.3605367 , 0.33611554, ..., 0.8466814 , 0.8142395 ,
#          0.72548044]], dtype=float32),
#  array([[0.21719368, 0.196046  , 0.23494641, ..., 0.7432884 , 0.6993423 ,
#          0.6965313 ],
#         [0.2830532 , 0.24354655, 0.2360725 , ..., 0.73877186, 0.76718694,
#          0.7664822 ],
#         [0.25277355, 0.2587619 , 0.22034897, ..., 0.6924138 , 0.6741982 ,
#          0.7461388 ],
#         ...,
#         [0.5951326 , 0.57102543, 0.5670639 , ..., 1.3016127 , 1.3981383 ,
#          1.2822487 ],
#         [0.59232223, 0.55111796, 0.58221054, ..., 1.1849191 , 1.2611562 ,
#          1.2886113 ],
#         [0.5511432 , 0.5653265 , 0.63706815, ..., 0.970166  , 1.060376  ,
#          1.1340075 ]], dtype=float32),
#  array([[0.20041625, 0.20998101, 0.1855479 , ..., 0.2598931 , 0.2387745 ,
#          0.2946233 ],
#         [0.13794377, 0.16945876, 0.22948343, ..., 0.2557983 , 0.2649256 ,
#          0.23625802],
#         [0.13192374, 0.14762442, 0.17166162, ..., 0.26861098, 0.28925547,
#          0.208591  ],
#         ...,
#         [0.3823897 , 0.445082  , 0.54186386, ..., 0.85469216, 0.7547193 ,
#          0.7454207 ],
#         [0.3835655 , 0.40141147, 0.4194713 , ..., 0.8016778 , 0.7326058 ,
#          0.78807956],
#         [0.29279536, 0.3148781 , 0.3859861 , ..., 0.8708716 , 0.8052949 ,
#          0.78646237]], dtype=float32),
#  array([[0.3621869 , 0.27253807, 0.32629198, ..., 0.19780084, 0.18239653,
#          0.15436442],
#         [0.41652787, 0.4027415 , 0.39621815, ..., 0.1755284 , 0.1897429 ,
#          0.19135724],
#         [0.55289865, 0.42982548, 0.45462713, ..., 0.21368444, 0.17111781,
#          0.17284098],
#         ...,
#         [0.97696567, 1.1564027 , 1.1663245 , ..., 0.7709497 , 0.79806364,
#          0.9794891 ],
#         [0.9245063 , 1.0220482 , 1.106465  , ..., 0.5960047 , 0.6280465 ,
#          0.75834787],
#         [0.89294076, 0.87264234, 0.9597738 , ..., 0.62194955, 0.47516143,
#          0.54873025]], dtype=float32),
#  array([[0.22873107, 0.2031696 , 0.26427522, ..., 0.25507283, 0.31732094,
#          0.20205513],
#         [0.21448381, 0.19393028, 0.25197846, ..., 0.22660206, 0.21669507,
#          0.20170319],
#         [0.17830124, 0.21304831, 0.30215982, ..., 0.21765165, 0.24737693,
#          0.21704458],
#         ...,
#         [0.89112526, 1.038089  , 0.96950835, ..., 0.66578805, 0.70359766,
#          0.8546608 ],
#         [0.70428133, 0.924491  , 0.9557453 , ..., 0.7392869 , 0.77293706,
#          0.8284062 ],
#         [0.71287596, 0.7756582 , 1.0570153 , ..., 0.86621404, 0.92580944,
#          0.8192813 ]], dtype=float32),
#  array([[0.28902975, 0.35272214, 0.4588585 , ..., 0.18052691, 0.14144066,
#          0.21186373],
#         [0.2896308 , 0.42010447, 0.56365263, ..., 0.2500935 , 0.1740513 ,
#          0.1582504 ],
#         [0.2412007 , 0.39386964, 0.5171765 , ..., 0.20385696, 0.182725  ,
#          0.17446819],
#         ...,
#         [0.822657  , 0.9454919 , 0.9092447 , ..., 1.2616278 , 1.3561928 ,
#          0.27354655],
#         [0.8604718 , 0.9589521 , 0.9971259 , ..., 1.1871816 , 1.3202801 ,
#          0.25660163],
#         [0.9252539 , 1.1100748 , 1.2178897 , ..., 1.1336356 , 1.2371768 ,
#          0.19412526]], dtype=float32),
#  array([[3.9823857e-01, 3.4626332e-01, 4.0737224e-01, ..., 8.9938527e-05,
#          2.6770879e-06, 0.0000000e+00],
#         [3.8773558e-01, 3.5526377e-01, 2.7235827e-01, ..., 4.3557215e-05,
#          1.3099636e-06, 0.0000000e+00],
#         [4.0587759e-01, 3.5645694e-01, 2.9074702e-01, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         ...,
#         [6.2209523e-01, 6.3475978e-01, 8.2879156e-01, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [4.8992410e-01, 5.6119663e-01, 6.2821758e-01, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [5.0416350e-01, 4.6198964e-01, 4.6121287e-01, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00]], dtype=float32),
#  array([[0.20428531, 0.32397598, 0.23890756, ..., 0.        , 0.        ,
#          0.        ],
#         [0.27658722, 0.2512188 , 0.2180529 , ..., 0.        , 0.        ,
#          0.        ],
#         [0.19571535, 0.22599763, 0.21361022, ..., 0.        , 0.        ,
#          0.        ],
#         ...,
#         [1.0487245 , 1.0749516 , 1.1303133 , ..., 0.        , 0.        ,
#          0.        ],
#         [0.93161494, 0.9861478 , 0.96484935, ..., 0.        , 0.        ,
#          0.        ],
#         [0.82110316, 0.8412598 , 0.937039  , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.0218921e+00, 1.0129439e+00, 9.6247762e-01, ..., 7.3190881e-07,
#          0.0000000e+00, 0.0000000e+00],
#         [1.0147256e+00, 1.0047625e+00, 1.0406264e+00, ..., 2.3537273e-06,
#          0.0000000e+00, 0.0000000e+00],
#         [9.0960842e-01, 9.6879047e-01, 1.0692217e+00, ..., 3.2162770e-06,
#          0.0000000e+00, 0.0000000e+00],
#         ...,
#         [1.7611790e+00, 1.8065348e+00, 1.7859287e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [1.7916461e+00, 1.7257357e+00, 1.8375881e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [1.5572336e+00, 1.5336399e+00, 1.7082298e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00]], dtype=float32),
#  array([[1.0790945 , 0.86568624, 0.8120901 , ..., 0.42179927, 0.37614274,
#          0.38277492],
#         [0.97970587, 0.85237145, 0.8691404 , ..., 0.41763222, 0.3302007 ,
#          0.3402929 ],
#         [0.8832044 , 0.80992943, 0.90334815, ..., 0.4476817 , 0.38693908,
#          0.30881852],
#         ...,
#         [1.2817006 , 1.0746573 , 1.190156  , ..., 0.2074001 , 0.22842571,
#          0.18450427],
#         [1.2481337 , 1.0105512 , 1.100079  , ..., 0.26603514, 0.2354422 ,
#          0.1776939 ],
#         [1.1815462 , 1.0658686 , 1.0937845 , ..., 0.16688026, 0.18092789,
#          0.14358355]], dtype=float32),
#  array([[0.7911472 , 0.49294254, 0.4270368 , ..., 0.        , 0.        ,
#          0.        ],
#         [0.99374485, 0.6979483 , 0.55554867, ..., 0.        , 0.        ,
#          0.        ],
#         [0.8213925 , 0.600658  , 0.5918408 , ..., 0.        , 0.        ,
#          0.        ],
#         ...,
#         [1.0988443 , 1.0881426 , 1.0697138 , ..., 0.        , 0.        ,
#          0.        ],
#         [1.1220014 , 1.091715  , 1.0222665 , ..., 0.        , 0.        ,
#          0.        ],
#         [1.0041332 , 0.9315772 , 0.8615575 , ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  array([[1.2141758, 1.2285401, 1.2054473, ..., 0.       , 0.       ,
#          0.       ],
#         [1.2152928, 1.3159474, 1.2469846, ..., 0.       , 0.       ,
#          0.       ],
#         [1.0827802, 1.3072267, 1.1783286, ..., 0.       , 0.       ,
#          0.       ],
#         ...,
#         [1.0281031, 1.007117 , 1.003992 , ..., 0.       , 0.       ,
#          0.       ],
#         [1.1372958, 1.119664 , 1.0770899, ..., 0.       , 0.       ,
#          0.       ],
#         [1.2305313, 1.080156 , 0.9984475, ..., 0.       , 0.       ,
#          0.       ]], dtype=float32),
#  array([[0.8875999 , 0.986285  , 0.9212724 , ..., 1.2392796 , 1.2947875 ,
#          0.96239156],
#         [0.87771785, 0.88000053, 0.9244252 , ..., 1.2765837 , 1.2851423 ,
#          0.9800423 ],
#         [0.8316187 , 0.84549546, 0.86978143, ..., 1.1929166 , 1.1622707 ,
#          1.1019056 ],
#         ...,
#         [0.98006463, 1.0671916 , 1.251113  , ..., 0.44165823, 0.49676648,
#          0.70565283],
#         [1.0622466 , 1.1635538 , 1.2212831 , ..., 0.46123537, 0.4437935 ,
#          0.59362197],
#         [0.9547341 , 1.1041211 , 1.0791817 , ..., 0.5440633 , 0.46827313,
#          0.5353992 ]], dtype=float32),
#  array([[0.7644454 , 0.8640298 , 0.9513387 , ..., 0.8552388 , 0.9462053 ,
#          0.99613917],
#         [0.70703715, 0.86377025, 0.89629394, ..., 0.8785686 , 0.9724942 ,
#          1.0047978 ],
#         [0.5950339 , 0.76434714, 0.8288088 , ..., 0.83311415, 0.9056652 ,
#          0.97293985],
#         ...,
#         [0.30284232, 0.32169643, 0.3281755 , ..., 1.0071042 , 0.94434977,
#          0.88200665],
#         [0.29039395, 0.3334415 , 0.28336573, ..., 1.1208068 , 0.9905132 ,
#          0.9350836 ],
#         [0.32150975, 0.2816716 , 0.16708256, ..., 1.2013856 , 1.1295301 ,
#          1.0742776 ]], dtype=float32),
#  array([[0.62240386, 0.6112239 , 0.5773327 , ..., 0.7739955 , 0.76642066,
#          0.83934546],
#         [0.593153  , 0.45902658, 0.5227268 , ..., 1.0069834 , 0.8924753 ,
#          0.86411685],
#         [0.6611184 , 0.4786943 , 0.47022602, ..., 1.0751069 , 0.9937141 ,
#          0.76613975],
#         ...,
#         [0.20480628, 0.17424363, 0.27087352, ..., 1.0519825 , 1.0287511 ,
#          1.0262166 ],
#         [0.20374592, 0.19693309, 0.23876859, ..., 1.0366377 , 1.0707309 ,
#          1.1323583 ],
#         [0.23021913, 0.22074024, 0.26721388, ..., 0.9865994 , 1.0364652 ,
#          1.2018303 ]], dtype=float32),
#  array([[9.2315114e-01, 7.2265679e-01, 7.8629923e-01, ..., 9.0812576e-01,
#          1.0092860e+00, 9.5033520e-01],
#         [9.4785178e-01, 6.9273204e-01, 7.8867120e-01, ..., 8.5748911e-01,
#          9.8603272e-01, 9.3717390e-01],
#         [9.0861541e-01, 6.1010307e-01, 6.9323802e-01, ..., 8.9078999e-01,
#          9.2719179e-01, 9.5823199e-01],
#         ...,
#         [1.8670671e-01, 1.8881865e-01, 1.8605560e-01, ..., 2.1321982e-02,
#          1.0348337e-03, 1.2111686e-03],
#         [1.8647003e-01, 1.8086545e-01, 2.1179883e-01, ..., 1.3730768e-02,
#          6.9733907e-04, 1.1544917e-03],
#         [1.5883842e-01, 1.9027793e-01, 2.0579749e-01, ..., 1.1809782e-02,
#          5.6488236e-04, 1.1262308e-03]], dtype=float32),
#  array([[3.6273798e-01, 2.9888576e-01, 2.6677862e-01, ..., 7.6010224e-06,
#          7.7953940e-04, 1.4184813e-04],
#         [3.5189825e-01, 2.5562450e-01, 2.1680772e-01, ..., 2.4261652e-04,
#          8.5601362e-04, 1.5138234e-04],
#         [4.4521865e-01, 3.6609519e-01, 2.9431403e-01, ..., 2.7728037e-04,
#          9.8832219e-04, 1.7053905e-04],
#         ...,
#         [1.4945748e-01, 2.0558575e-01, 2.3858409e-01, ..., 6.4582741e-01,
#          6.8720639e-01, 6.8641627e-01],
#         [1.6008653e-01, 2.1077234e-01, 1.9248196e-01, ..., 6.6859037e-01,
#          7.2799623e-01, 7.5732559e-01],
#         [1.5144071e-01, 1.9553840e-01, 1.8028426e-01, ..., 7.4525356e-01,
#          8.3490676e-01, 7.8460813e-01]], dtype=float32),
#  array([[2.7909234e-01, 2.9243675e-01, 2.8934568e-01, ..., 8.8482397e-03,
#          1.7240469e-03, 1.3836472e-04],
#         [2.8404078e-01, 2.3379482e-01, 2.4359973e-01, ..., 8.8482397e-03,
#          1.7240469e-03, 1.3836472e-04],
#         [2.5699383e-01, 2.2486910e-01, 2.3749849e-01, ..., 8.8482397e-03,
#          1.7240469e-03, 1.3836472e-04],
#         ...,
#         [8.9625478e-01, 7.5001609e-01, 7.1992135e-01, ..., 9.1027915e-01,
#          6.2517947e-01, 1.1103649e-01],
#         [7.7911431e-01, 6.9274372e-01, 7.6499295e-01, ..., 1.0723466e+00,
#          7.4731797e-01, 1.4840539e-01],
#         [7.7720433e-01, 6.3976490e-01, 7.2880745e-01, ..., 1.3314205e+00,
#          1.0642416e+00, 1.4240626e-01]], dtype=float32),
#  array([[0.37251186, 0.29891124, 0.44978282, ..., 1.5113791 , 1.1768101 ,
#          0.7043023 ],
#         [0.42191   , 0.30666232, 0.34425235, ..., 1.615733  , 1.197868  ,
#          0.7473678 ],
#         [0.40509775, 0.4144833 , 0.35950705, ..., 1.566182  , 1.2819531 ,
#          0.7143221 ],
#         ...,
#         [0.79439723, 0.8464488 , 0.8732635 , ..., 0.8145631 , 0.74524164,
#          0.9031018 ],
#         [0.8156859 , 0.9583406 , 0.96990174, ..., 0.78888184, 0.76936686,
#          0.9386024 ],
#         [0.8857506 , 1.0035746 , 0.98235464, ..., 0.8151597 , 0.74350005,
#          0.9198476 ]], dtype=float32),
#  array([[0.43511933, 0.48088804, 0.447918  , ..., 0.21266238, 0.01414818,
#          0.07827501],
#         [0.28150398, 0.29468215, 0.27201933, ..., 0.27161032, 0.01347458,
#          0.07823616],
#         [0.34865296, 0.29430544, 0.2505513 , ..., 0.2470959 , 0.01279463,
#          0.07821701],
#         ...,
#         [0.6789593 , 0.70184004, 0.8426899 , ..., 1.6319689 , 0.13812006,
#          0.07803999],
#         [0.6439335 , 0.7336819 , 0.88817143, ..., 1.5472844 , 0.13691014,
#          0.07816942],
#         [0.70191485, 0.8930996 , 1.0085883 , ..., 1.4572924 , 0.12628776,
#          0.07823797]], dtype=float32),
#  array([[1.2604448 , 1.1732435 , 0.96903855, ..., 0.        , 0.        ,
#          0.        ],
#         [1.2810344 , 1.2208505 , 1.0251317 , ..., 0.        , 0.        ,
#          0.        ],
#         [1.1193734 , 1.0770502 , 1.0650545 , ..., 0.        , 0.        ,
#          0.        ],
#         ...,
#         [0.8334437 , 0.9423769 , 0.9909261 , ..., 0.28457612, 0.21158153,
#          0.02605738],
#         [0.86390805, 0.9082744 , 0.946779  , ..., 0.2881272 , 0.28858888,
#          0.02668285],
#         [0.94825596, 1.0312288 , 1.1185393 , ..., 0.28581068, 0.27245787,
#          0.01883638]], dtype=float32),
#  array([[1.0980144e+00, 1.0344670e+00, 9.4559729e-01, ..., 1.4533033e-04,
#          1.7512593e-05, 6.4897029e-07],
#         [1.0984808e+00, 1.1382776e+00, 1.0811610e+00, ..., 1.4016869e-04,
#          1.6998529e-05, 6.3151799e-07],
#         [1.1042444e+00, 1.1561333e+00, 1.1195199e+00, ..., 1.3355992e-04,
#          1.6355991e-05, 6.0997962e-07],
#         ...,
#         [1.3545711e+00, 1.1299285e+00, 9.9176627e-01, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [1.2986683e+00, 1.1329210e+00, 1.0010791e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00],
#         [1.2646240e+00, 1.0841449e+00, 1.0122581e+00, ..., 0.0000000e+00,
#          0.0000000e+00, 0.0000000e+00]], dtype=float32),
#  array([[0.31442568, 0.31359154, 0.37309578, ..., 0.1735727 , 0.25204733,
#          0.22185865],
#         [0.34047273, 0.27709058, 0.2939013 , ..., 0.17137444, 0.1696224 ,
#          0.22379667],
#         [0.33682486, 0.30699772, 0.27060756, ..., 0.23684518, 0.16704382,
#          0.18475696],
#         ...,
#         [0.7600724 , 0.64863575, 0.6451783 , ..., 0.71089727, 0.7097308 ,
#          0.6827907 ],
#         [0.7034588 , 0.61989456, 0.72556674, ..., 0.6835237 , 0.7368085 ,
#          0.76039   ],
#         [0.6579965 , 0.64896566, 0.7565759 , ..., 0.6779667 , 0.6718993 ,
#          0.8468827 ]], dtype=float32),
#  array([[0.35519397, 0.421166  , 0.38027292, ..., 0.5678584 , 0.558881  ,
#          0.55324066],
#         [0.30742633, 0.31223586, 0.43995935, ..., 0.59284073, 0.7047236 ,
#          0.66611415],
#         [0.36518228, 0.47040528, 0.36707538, ..., 0.592326  , 0.6358872 ,
#          0.66514945],
#         ...,
#         [0.75481385, 0.66508806, 0.77816916, ..., 0.8773393 , 0.8680534 ,
#          0.8779224 ],
#         [0.61434484, 0.638179  , 0.7193516 , ..., 0.92685467, 0.8400366 ,
#          0.9128809 ],
#         [0.6522314 , 0.5483797 , 0.6253521 , ..., 0.9053145 , 0.8889752 ,
#          0.8920134 ]], dtype=float32),
#  array([[0.7021509 , 0.71626455, 0.7816452 , ..., 0.        , 0.        ,
#          0.        ],
#         [0.7279886 , 0.7384551 , 0.833299  , ..., 0.        , 0.        ,
#          0.        ],
#         [0.6862042 , 0.74762845, 0.7670252 , ..., 0.        , 0.        ,
#          0.        ],
#         ...,
#         [0.27848274, 0.2155322 , 0.28165093, ..., 0.        , 0.        ,
#          0.        ],
#         [0.21970534, 0.26327443, 0.319826  , ..., 0.        , 0.        ,
#          0.        ],
#         [0.288157  , 0.32345444, 0.28794807, ..., 0.        , 0.        ,
#          0.        ]], dtype=float32),
#  array([[0.89554703, 0.92478305, 0.9885946 , ..., 0.92452586, 0.8113072 ,
#          0.7611907 ],
#         [1.0914295 , 0.9820322 , 0.9813887 , ..., 0.9163427 , 0.80167454,
#          0.78573024],
#         [1.1237121 , 0.9751937 , 0.92316204, ..., 0.86106724, 0.84183395,
#          0.81968427],
#         ...,
#         [0.19878793, 0.21012327, 0.20180011, ..., 0.46968493, 0.3755053 ,
#          0.42295924],
#         [0.25815356, 0.28059646, 0.37136945, ..., 0.5581418 , 0.3805023 ,
#          0.3460174 ],
#         [0.34560743, 0.47920004, 0.53273743, ..., 0.3858482 , 0.26236138,
#          0.30148816]], dtype=float32),
#  array([[0.6534847 , 0.70073634, 0.8020906 , ..., 0.993956  , 0.9512233 ,
#          0.9051407 ],
#         [0.5602909 , 0.6477515 , 0.7381022 , ..., 1.0324585 , 0.90972716,
#          0.86667085],
#         [0.5889917 , 0.6385046 , 0.6448601 , ..., 1.0062804 , 0.94247013,
#          0.9002367 ],
#         ...,
#         [0.32684565, 0.23796833, 0.24573389, ..., 0.18932499, 0.16668949,
#          0.15646137],
#         [0.34805423, 0.21442163, 0.23123208, ..., 0.20640522, 0.18979453,
#          0.18176742],
#         [0.31032747, 0.20127194, 0.1857257 , ..., 0.20327479, 0.21042088,
#          0.18541563]], dtype=float32),
#  array([[0.634417  , 0.61485916, 0.6586197 , ..., 0.33079895, 0.24872075,
#          0.211339  ],
#         [0.64028543, 0.63317776, 0.53636163, ..., 0.25994208, 0.25878024,
#          0.31821585],
#         [0.64571005, 0.6991966 , 0.69653034, ..., 0.28190732, 0.28905046,
#          0.44462776],
#         ...,
#         [1.0636703 , 0.94374055, 0.8700686 , ..., 0.5971977 , 0.6210241 ,
#          0.6662706 ],
#         [1.0040011 , 0.95954007, 0.87132865, ..., 0.510312  , 0.5848074 ,
#          0.6179575 ],
#         [1.1024691 , 0.85202837, 0.70774895, ..., 0.6077141 , 0.6755814 ,
#          0.65897983]], dtype=float32),
#  array([[0.9793688 , 0.9812052 , 1.103202  , ..., 0.27911678, 0.20868643,
#          0.23591301],
#         [0.8580662 , 1.0197964 , 1.0982562 , ..., 0.2839863 , 0.33890057,
#          0.31683996],
#         [1.0130478 , 1.1182361 , 1.2487018 , ..., 0.24038263, 0.31182495,
#          0.4358366 ],
#         ...,
#         [1.2091502 , 1.1254367 , 1.1139138 , ..., 0.75126   , 0.7356936 ,
#          0.6622701 ],
#         [1.1636593 , 1.0498794 , 1.0005974 , ..., 0.74150544, 0.6251034 ,
#          0.6346674 ],
#         [1.1855003 , 1.0840747 , 0.90168667, ..., 0.6546161 , 0.66790265,
#          0.69347674]], dtype=float32),
#  array([[0.9797494 , 0.8624966 , 0.7259954 , ..., 0.21027006, 0.23102279,
#          0.19210303],
#         [0.76722425, 0.7227583 , 0.75189406, ..., 0.15885319, 0.19649948,
#          0.187448  ],
#         [0.6564152 , 0.68276864, 0.7126921 , ..., 0.18652329, 0.20749061,
#          0.26469445],
#         ...,
#         [0.7100689 , 0.733786  , 0.7705831 , ..., 0.9320592 , 0.71075743,
#          0.8336878 ],
#         [0.7519987 , 0.77620935, 0.86420876, ..., 0.764732  , 0.75793093,
#          0.8704698 ],
#         [0.869365  , 0.8692695 , 0.94477427, ..., 0.7713944 , 0.8537426 ,
#          0.8685995 ]], dtype=float32),
#  array([[0.9406442 , 0.97430146, 0.97619843, ..., 1.0749191 , 0.93269944,
#          1.2443506 ],
#         [0.99647397, 1.0549973 , 1.0841143 , ..., 0.8925409 , 0.77116066,
#          1.0573592 ],
#         [1.0397427 , 1.0100961 , 1.044223  , ..., 0.8136788 , 0.85003   ,
#          1.0866784 ],
#         ...,
#         [0.25785384, 0.26052922, 0.23757245, ..., 0.5178569 , 0.2613113 ,
#          0.26241165],
#         [0.2791906 , 0.29770905, 0.2467356 , ..., 0.45592564, 0.31734216,
#          0.28917763],
#         [0.30161104, 0.21476334, 0.13431844, ..., 0.2782505 , 0.22415824,
#          0.2825811 ]], dtype=float32),
#  array([[1.0212177 , 0.90457135, 0.85439086, ..., 0.8603145 , 0.93084913,
#          0.8957872 ],
#         [0.9787815 , 0.9098638 , 0.97003394, ..., 0.659056  , 0.8868146 ,
#          0.96278936],
#         [0.96940124, 0.99040985, 1.0502088 , ..., 0.6688438 , 0.7821723 ,
#          0.9713537 ],
#         ...,
#         [0.518495  , 0.6747648 , 0.5362515 , ..., 0.39271858, 0.45325044,
#          0.36267504],
#         [0.40946525, 0.40385833, 0.2971239 , ..., 0.31056753, 0.36102477,
#          0.32707265],
#         [0.30494547, 0.37689623, 0.24667299, ..., 0.31184107, 0.38882858,
#          0.3506115 ]], dtype=float32),
#  array([[0.24917251, 0.3269431 , 0.22756356, ..., 0.44120875, 0.42866427,
#          0.45761156],
#         [0.49473953, 0.43552697, 0.29538497, ..., 0.37973237, 0.50610924,
#          0.48943532],
#         [0.71331066, 0.6424053 , 0.3654476 , ..., 0.3918181 , 0.5069217 ,
#          0.4498433 ],
#         ...,
#         [0.29722893, 0.2661865 , 0.27589118, ..., 1.6289227 , 1.5167102 ,
#          1.3739647 ],
#         [0.24743816, 0.31136766, 0.29304266, ..., 1.595956  , 1.524641  ,
#          1.3836615 ],
#         [0.2513742 , 0.25221887, 0.30302483, ..., 1.5768527 , 1.5434077 ,
#          1.4750487 ]], dtype=float32),
#  array([[1.4397937 , 1.4648309 , 1.3351747 , ..., 0.32557344, 0.41786924,
#          0.36647275],
#         [1.4775811 , 1.4177699 , 1.3287383 , ..., 0.2894514 , 0.3282826 ,
#          0.34790164],
#         [1.4447811 , 1.4036812 , 1.3368713 , ..., 0.2932173 , 0.33195704,
#          0.37860397],
#         ...,
#         [1.5977228 , 1.83023   , 1.8216355 , ..., 1.5167439 , 1.455016  ,
#          1.4049433 ],
#         [1.6872089 , 1.8710731 , 1.8643539 , ..., 1.5535129 , 1.4824685 ,
#          1.4239616 ],
#         [1.7065647 , 1.8746473 , 1.8623261 , ..., 1.5993904 , 1.5612466 ,
#          1.4890187 ]], dtype=float32),
#  array([[2.4003363e-01, 2.3424025e-01, 2.3742254e-01, ..., 1.0322093e-03,
#          3.0256359e-05, 0.0000000e+00],
#         [2.5716579e-01, 2.6828101e-01, 2.0708229e-01, ..., 1.0322093e-03,
#          3.0256359e-05, 0.0000000e+00],
#         [1.7292470e-01, 2.3586676e-01, 2.7955410e-01, ..., 1.0322093e-03,
#          3.0256359e-05, 0.0000000e+00],
#         ...,
#         [5.4749340e-01, 4.5052668e-01, 3.0980471e-01, ..., 5.5614836e-03,
#          3.3713281e-04, 4.4872500e-05],
#         [4.8915491e-01, 3.6497146e-01, 2.4064325e-01, ..., 4.3475521e-03,
#          2.9306879e-04, 9.4596573e-05],
#         [2.9698434e-01, 2.6628044e-01, 2.4362004e-01, ..., 5.6686043e-03,
#          1.0400725e-03, 1.4327306e-04]], dtype=float32)]

# %% [markdown]
# ### Holes extracted from segmented CL
#
# Scan C_4_preop is an outlier (originally C_4_preopb because of re-assembly), needs dedicated segmentation

# %%
with open(os.path.join(toppath, 'ABCZ_CLhole_segmented', 'CL_hole_area.csv')) as f:
    datalines = f.readlines()

with open(os.path.join(toppath, 'DE_CLhole_segmented', 'CL_hole_area.csv')) as f:
    datalines2 = f.readlines()

datalines = datalines + datalines2[1:]

# %%
hole_dict = {}

for line in datalines[1:]:
    splitline = line.split(' , ')
    valstr = splitline[1]#1 for pseudo CFD, 2 for projection
    if '\n' in valstr: valstr = valstr[:-1] # strip the newline character if necessary, pretty ugly and not robust, but works for the csv produced by 04_....
    val = float(valstr) 
    splitsplit =  splitline[0].split('_')
    ser = splitsplit[0]
    sample = splitsplit[1]
    stage = ''.join([i+'_' for i in splitsplit[2:]])[:-1]
    if not ser in hole_dict.keys(): hole_dict[ser] = {}
    if not sample in  hole_dict[ser].keys():  hole_dict[ser][sample] = {}
    hole_dict[ser][sample][stage] = val

# %%
def plot_absolute_hole_area(ab, current, i):
    ser = ab.split('_')[0]
    sample = ab.split('_')[1]
    color=cm.tab10(i)
    color_choices = {'A': 0, 'B': 1, 'C': 2, 'Z': 3}
    color = cm.tab10(color_choices[ser])
    for key in hole_dict[ser][sample].keys():
        val = hole_dict[ser][sample][key]
        Q = 0
        marker = 'o'
        if key == 'postop_1':
            Q = 1
            marker = '^'
        if key == 'postop_2':
            Q = 2
            marker = 's'
        if key=='preop':
            plt.plot(current, val, marker=marker, label=ser+'_'+sample, color=color)
        else:
            plt.plot(current, val, marker=marker,  color=color)

# %%
current_25 = ['A_3', 'B_2', 'C_4']
current_50 = ['A_4', 'B_1', 'C_1', 'D_2', 'E_3']
current_50_special = ['A_6', 'C_5']
current_80_special = ['A_11', 'A_9', 'B_4']
current_100 = ['A_12', 'C_2', 'D_1', 'E_4']
current_150 = ['C_3']#, 'Z_4'] # Z_4 pretty damaged during assembly
current_high_special = ['A_13', 'A_11']

# %%
i = 0
for ab in current_25:
    plot_absolute_hole_area(ab, 25, i)
    i = i+1
i = 0
for ab in current_50:
    plot_absolute_hole_area(ab, 50, i)
    i = i+1
i = 0
for ab in current_100:
    plot_absolute_hole_area(ab, 100, i)
    i = i+1
i = 0
for ab in current_150:
    plot_absolute_hole_area(ab, 150, i)
    i = i+1
# i = 0
# for ab in current_80_special:
#     plot_absolute_hole_area(ab, 80, i)
#     i = i+1
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 7
#       5 i = 0
#       6 for ab in current_50:
# ----> 7     plot_absolute_hole_area(ab, 50, i)
#       8     i = i+1
#       9 i = 0
#
# Cell In[15], line 6, in plot_absolute_hole_area(ab, current, i)
#       4 color=cm.tab10(i)
#       5 color_choices = {'A': 0, 'B': 1, 'C': 2, 'Z': 3}
# ----> 6 color = cm.tab10(color_choices[ser])
#       7 for key in hole_dict[ser][sample].keys():
#       8     val = hole_dict[ser][sample][key]
#
# KeyError: 'D'

# %% [markdown]
# ### Electrochemistry

# %%
# TODO: extract exact charge for every sample to populate Xarray
# TODO: timestamp of CT to automatically extract echem charge

### nanotom time most of time wrong, roughly 10min, make automatic EClab file detection robust!!!

# %%
def get_raw_files(series, raw_file_dict):
    raw_file_dict[series] = {}
    series_path = os.path.join(toppath, series+'_series')
    folders = os.listdir(series_path)
    samples = []
    for sample in folders:
        samples.append(sample.split('_')[-1])
    paths = []
    for sample in samples:
        if series == 'Z' and sample in ['1', '2', '6']: continue
        raw_file_dict[series][sample] = {}
        sample_path = os.path.join(toppath, series+'_series', series+'_'+sample)
    
        files = os.listdir(sample_path)
        stages = []
        for file in files:
            splitfile = file.split('_')
            if splitfile[-1] == 'rotcrop.tif':
                stage = ''.join([i+'_' for i in splitfile[2:-1]])
                stages.append(stage)
        raw_files = []
        for stage in stages:
            imroot = series+'_'+sample+'_'+stage
            raw_file = os.path.join(sample_path, series+'_'+sample+'_'+stage[:-1], series+'_'+sample+'_'+stage+'.pcp')
            # print(raw_file)
            if os.path.exists(raw_file):
                raw_file_dict[series][sample][stage] = raw_file
            else:
                raw_file_dict[series][sample][stage] = None
                print(series+' '+sample+' '+stage+' pcp file not found.')

    return raw_file_dict

# %%
raw_file_dict = {}
raw_file_dict = get_raw_files('A',raw_file_dict) 
raw_file_dict = get_raw_files('B',raw_file_dict) 
raw_file_dict =get_raw_files('C',raw_file_dict) 
raw_file_dict =get_raw_files('Z',raw_file_dict)
# Out:
# A 3 postop_1_ pcp file not found.
# A 9 postop_1_ pcp file not found.
# A 11 postop_1_ pcp file not found.
# A 6 postop_1_ pcp file not found.
# B 5 postop_1_ pcp file not found.
# B 4 postop_1_ pcp file not found.
# B 2 postop_1_ pcp file not found.
# B 6 wet_2_ pcp file not found.
# C 5 postop_1_ pcp file not found.
# C 1 postop_2_ pcp file not found.
# Z 3 preop_ pcp file not found.
# Z 4 postop_1_ pcp file not found.
# Z 4 postop_2_ pcp file not found.

# %%
raw_file_dict['A']['3']['postop_1_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_3/A_1_postop_1/A_1_postop_1_.pcp'
raw_file_dict['A']['9']['postop_1_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_9/A_9_postop/A_9_postop_.pcp'
raw_file_dict['A']['11']['postop_1_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_11/A_11_postop/A_11_postop_.pcp'
raw_file_dict['A']['6']['postop_1_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/A_series/A_6/A_6_postop/A_6_postop_.pcp'
raw_file_dict['B']['5']['postop_1_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_5/B_5_postop/B_5_postop_.pcp'
raw_file_dict['B']['4']['postop_1_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_4/B_4_postop/B_4_postop_.pcp'
raw_file_dict['B']['2']['postop_1_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_2/B_2_postop1/B_2_postop1_.pcp'
raw_file_dict['B']['6']['wet_2_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/B_series/B_6/B_6_wet_2_40C/B_6_wet_2_40C_.pcp'
raw_file_dict['C']['5']['postop_1_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_5/C_5_postop/C_5_postop_.pcp'
raw_file_dict['C']['1']['postop_2_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/C_series/C_1/C_1_postop_2b/C_1_postop_2b_.pcp'
raw_file_dict['Z']['3']['preop_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/Z_series/Z_3/Z3_preop/Z3_preop_.pcp'
raw_file_dict['Z']['4']['postop_1_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/Z_series/Z_4/Z_4_postop1/Z_4_postop1_.pcp'
raw_file_dict['Z']['4']['postop_2_'] = '/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/Z_series/Z_4/Z_4_postop2/Z_4_postop2_.pcp'

# %%
def read_timestamp_from_file(path):
    with open(path) as file:
        lines = file.readlines()
        timestamp = lines[500].split('\t')[-1][:-1] #line 500 in the middle of the acquisition to circumvent issue with clocks not macthcing between the different computers
    return timestamp

def convert_to_t_utc(timestamp):
    dtime = datetime.strptime(timestamp,'%Y-%m-%d %H:%M:%S')

def get_scan_timestamp(raw_file_dict):
    timestamps = {}
    series = list(raw_file_dict.keys())

    for ser in series:
        timestamps[ser] = {}
        samples = list(raw_file_dict[ser].keys())
        for sample in samples:
            timestamps[ser][sample] = {}
            stages = list(raw_file_dict[ser][sample].keys())
            for stage in stages:
                path = raw_file_dict[ser][sample][stage]
                timestamp = read_timestamp_from_file(path)
                dt = datetime.strptime(timestamp,'%Y-%m-%d %H:%M:%S')
                timestamps[ser][sample][stage] = {'original': timestamp, 't_utc': dt.timestamp()}
    return timestamps

# %%
def mean_mpr_timestamp(path):
    mpr_file = BioLogic.MPRfile(path)
    t2 = os.path.getmtime(path)
    try:
        t1 = mpr_file.timestamp.timestamp()
    except:
        t1 = t2

    return (t1+t2)/2

# %%
timestamps = get_scan_timestamp(raw_file_dict)

# %%
def assign_sample_files(folder, CTtimestamp):
    rawfiles = os.listdir(folder)
    files = []
    for file in rawfiles:
        if file[-3:] == 'mpr':
            path = os.path.join(folder, file)
            ECtimestamp = mean_mpr_timestamp(path)
            if ECtimestamp<CTtimestamp:
                files.append([file, path])
    return files

series = list(timestamps.keys())
for ser in series:
    samples = list(timestamps[ser].keys())
    for sample in samples:
        if ser == 'B' and sample == '6': continue
        if ser == 'Z' and sample == '7': continue
        ECfolder = os.path.join(toppath, 'Electrochemistry', '02_EC_data', ser+'_series', ser+'_'+sample)
        stages = list(timestamps[ser][sample].keys())
        for stage in stages:
            CTtimestamp = timestamps[ser][sample][stage]['t_utc']
            files = assign_sample_files(ECfolder, CTtimestamp)
            timestamps[ser][sample][stage]['mpr_files'] = files

# %%
import json

# %%
timestamps_and_files_path = os.path.join(toppath, 'CT_EC_linking_ABCDEZ.json')

# %%
# with open(timestamps_and_files_path, "w") as outfile:
#     json.dump(timestamps, outfile,indent = 4)

# %%
timestamps = json.load(open(timestamps_and_files_path))
data = timestamps.copy()

# %%
def get_total_charge_per_file(df):
    """
    works for negative currents throughout
    """
    Qraw = df['(Q-Qo)/mA.h']
    Qraw = Qraw[np.isfinite(Qraw)] #check for failed measurements, typically aborted
    if len(Qraw)>0:
        steps = np.argwhere((Qraw- np.roll(Qraw, 1))>0).flatten()
        Q = Qraw.copy()
        # for i in range(1,len(steps)):
        #     step = steps[i]
        #     correction = Qraw[steps[1]-1]
        #     for j in range(1, i):
        #         correction = correction + Qraw[steps[j]-1]
        #     Q[step:] = Qraw[step:] + correction
        for i in range(1,len(steps)):
            step = steps[i]
            Q[step:] = Qraw[step:] + Q[step-1]
        return Q.min()
    else:
        return 0

# %%
def get_charge(files):
    Qallfiles = 0
    Iallfiles = []
    for file in files:
        path = file[1]
        mpr_file = BioLogic.MPRfile(path)
        df = pd.DataFrame(mpr_file.data)
        Q = get_total_charge_per_file(df)
        I = np.nanmedian(df['<I>/mA'])
        Iallfiles.append(I)
        Qallfiles = Qallfiles + Q
    # convert from mA.h to As/cm2, active area 0.1cm2 hard coded
    Qallfiles = Qallfiles*3600/1000*10
    Iallfiles = np.nanmin(Iallfiles)*10
    return Qallfiles, Iallfiles

# %%
series = list(data.keys())
for ser in series:
    samples = list(data[ser].keys())
    for sample in samples:
        if ser == 'B' and sample == '6': continue
        if ser == 'Z' and sample == '7': continue
        stages = list(data[ser][sample].keys())
        for stage in stages:
            if stage == 'preop_':
                files = data[ser][sample]['postop_1_']['mpr_files']
                # get the current from the other file
                Q, I = get_charge(files)
                Q = 0
            else:
                files = data[ser][sample][stage]['mpr_files']
                Q, I = get_charge(files)
            # print(Q,I)
            data[ser][sample][stage]['Q [As/cm2]'] = Q
            data[ser][sample][stage]['I [mA/cm2]'] = I

# %%
def plot_charge(ab,current, i):
    ser = ab.split('_')[0]
    sample = ab.split('_')[1]
    color=cm.tab10(i)
    # color_choices = {'A': 0, 'B': 1, 'C': 2, 'Z': 3}
    # color = cm.tab10(color_choices[ser])
    for key in data[ser][sample].keys():
        val = -data[ser][sample][key]['Q [As/cm2]']
        marker = 'o'
        if key == 'postop_1_':
            marker = '^'
        if key == 'postop_2_':
            marker = 's'
        if key=='preop_':
            plt.plot(current, val, marker=marker, label=ser+'_'+sample, color=color)
        else:
            plt.plot(current, val, marker=marker, color=color)

# %%
def plot_charge_and_abs_damage(ab,I, norm):
    ser = ab.split('_')[0]
    sample = ab.split('_')[1]
    baseval = hole_dict[ser][sample]['preop']
    for key in hole_dict[ser][sample].keys():
        holeval = hole_dict[ser][sample][key]
        Q = -data[ser][sample][key+'_']['Q [As/cm2]']
        # I = -data[ser][sample][key]['I [A/cm2]']
        color = cmap(norm(Q))
        marker = 'o'
        if key == 'postop_1':
            marker = '^'
        if key == 'postop_2':
            marker = 's'
        plt.plot(I, holeval-baseval, marker=marker, color = color)

def plot_damage_vs_charge(ab,I, norm, ax, norm2,cmap, cmap2):
    ser = ab.split('_')[0]
    sample = ab.split('_')[1]
    baseval = hole_dict[ser][sample]['preop']
    if ab == 'C_4': baseval = 45000
    if ab == 'Z_4': baseval = 150000
    for key in hole_dict[ser][sample].keys():
        holeval = hole_dict[ser][sample][key]
        Q = -data[ser][sample][key+'_']['Q [As/cm2]']
        # I = -data[ser][sample][key]['I [A/cm2]']
        color = cmap(norm(I))
        # color = 'k'
        # if ser=='C' or ser=='Z': color='r'
        marker = 'o'
        txt = ab
        if key == 'postop_1':
            marker = '^'
            txt = txt+'a'
        if key == 'postop_2':
            marker = 's'
            txt = txt+'b'
        # marker = 's'            
        x, y = Q, (holeval-baseval)/1000/500*100
        ax.plot(x, y, marker=marker, color = color, markersize=7)
        # acolor = 'k'
        # if med_dict[ser][sample][key] > 0.99263966: acolor = 'r'
        med = med_dict[ser][sample][key]
        # ab = 'O'
        ax.annotate(txt, (x,y), color=cmap2(norm2(med)))

def linear(m, x0, label=None):
    x = np.arange(600)
    plt.plot(x, (x-x0)*m, 'k', alpha=0.3, label=label)

# %%
norm = Normalize(vmin=0,vmax=200)
d = 0.05
norm2 = Normalize(vmin=0.9-d,vmax=1.07-d)
fig, ax = plt.subplots(figsize = (10,5))
cmap = cm.viridis #inferno
cmap2 = cm.coolwarm # bwr
ax.scatter(df['charge'], df['damage'],marker='.', c = cmap(norm(df['current'])))#, alpha = 0.5)
ax.plot(0,0,'k^', label='1st charge interval')
ax.plot(0,0,'ks', label='2nd charge interval')
ax.plot(0,0,'k.', label='data by time-resolved XTM [1]')
i = 0
for ab in current_25:
    # if ab == 'C_4': continue
    plot_damage_vs_charge(ab,25, norm, ax, norm2, cmap, cmap2)
    i = i+1
i = 0
for ab in current_50:
    plot_damage_vs_charge(ab,50, norm, ax, norm2, cmap, cmap2)
    i = i+1
i = 0
for ab in current_100:
    plot_damage_vs_charge(ab,100, norm, ax, norm2, cmap, cmap2)
    i = i+1
i = 0
for ab in current_150:
    # if ab == 'Z_4': continue
    plot_damage_vs_charge(ab,150, norm, ax, norm2, cmap, cmap2)
    i = i+1
i = 0
for ab in current_80_special:
    plot_damage_vs_charge(ab,80, norm, ax, norm2, cmap, cmap2)
    i = i+1
i = 0
for ab in current_50_special:
    plot_damage_vs_charge(ab,50, norm, ax, norm2, cmap, cmap2)
    i = i+1
i = 0
for ab in current_high_special:
    plot_damage_vs_charge(ab,250,norm, ax, norm2, cmap, cmap2)
    i = i+1
# plt.legend()   
ax.set_xlabel('passed charge [As/cm$^2$]')
# plt.ylabel('Q [As/cm2]')
ax.set_ylabel('calibrated CL damage [%]')
fig.colorbar(plt.cm.ScalarMappable(norm=norm2, cmap=cmap2),
             ax=ax, label='median CL grayvalue')
fig.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
             ax=ax, label='current density [mA/cm$^2$]')



# plt.ylim(0)
m0 = 0.0155
# linear(m0,5, label = 'initial charge-damage relation')
plt.ylim(0,20)
plt.xlim(0,500)
plt.rc('legend', fontsize=13) #fontsize of the legend
plt.legend()
plt.rc('axes', labelsize=18) #fontsize of the x and y labels
# plt.savefig('/mpc/homes/fische_r/paper/07-coely-postmortem/sketch_images/charge_damage_with_tomcat.pdf', bbox_inches='tight')

# %%
med_dict = hole_dict.copy()

# %%
k = 0
for (ip, med) in zip(image_paths, meds):
    ser = ip[0]
    sample = ip[1]
    stage = ip[2]
    txt = ser+'_'+sample
    if stage == 'postop_1':
        txt = txt+'a'
    if stage == 'postop_2':
        txt = txt+'b'
    color='k'
    med_dict[ser][sample][stage] = med
    if med > 0.99263966: color = 'r'
    plt.plot(k, med, '.', color=color)
    plt.annotate(txt, (k, med),color=color)
    k = k+1

plt.ylabel('median CL layer gravalue maximum')
# Out:
# Text(0, 0.5, 'median CL layer gravalue maximum')

# %%
meds
# Out:
# []

# %%
tomcatdatapath = os.path.join(toppath, 'TOMCAT_reference_data', 'charge_damage_current_calib2.csv')

# %%
df = pd.read_csv(tomcatdatapath)

# %%
df
# Out:
#         charge    damage     current
# 0   -32.490565  0.023150   22.902693
# 1   -31.068339 -0.310267   24.241721
# 2   -29.573720 -0.293772   25.639298
# 3   -28.044184 -0.360685   25.673067
# 4   -26.495990 -0.140673   25.982224
# ..         ...       ...         ...
# 549  24.040554  0.789451  150.185424
# 550  28.564353  1.022487  149.631235
# 551  33.182536  1.126323  149.875864
# 552  38.034594  1.245304  199.945989
# 553  44.067598  1.718585  199.778438
#
# [554 rows x 3 columns]

# %%
mpr
