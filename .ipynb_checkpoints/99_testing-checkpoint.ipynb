# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import scipy as sp
import scipy.ndimage
import json
import skimage.io

toppath = '/mpc/homes/fische_r/nanotom_data/2023_COELY_postmortem'
processing_dict_path = os.path.join(toppath, 'processing_data.json')

# %%
series = 'D'
sample = '2'

# %%
sample_path = os.path.join(toppath, series+'_series', series+'_'+sample)
stage = 'preop'

# %%
outputpath = os.path.join(sample_path, series+'_'+sample+'_'+stage+'_rotcrop.tif')

# %%
im = skimage.io.imread(outputpath)

# %%
sample_path = os.path.join(toppath, series+'_series', series+'_'+sample)
stage = 'postop_2'

# %%
outputpath = os.path.join(sample_path, series+'_'+sample+'_'+stage+'_rotcrop.tif')

# %%
im2 = skimage.io.imread(outputpath)

# %%
vmin = -0.0587
vmax = 0.3144

# %%
plt.figure(figsize=(12,7))
plt.imshow(im[300:800,250,:], 'gray')

# %%
plt.figure(figsize=(12,7))
plt.imshow(im2[300:800,250,:], 'gray')

# %%
test = im[300:800,250,:].copy()

# %%
plt.imshow(test>0.3)

# %%
line = np.argmax(test>0.3, axis=1)

# %%
for i in range(len(line)):
    test[...,:line[i]+10] = 0

# %%
plt.imshow(test)

# %%
area = np.argmax(im>0.3, axis=2)

# %%
plt.imshow(im.max(axis=2))

# %%
area.mean()
# Out:
# 31.91831208791209

# %%
line.mean()
# Out:
# 28.726

# %%
np.median(area)
# Out:
# 28.0

# %%
def crop_cathode_CL(im):
    area = np.argmax(im>0.3, axis=2)
    med = np.median(area).astype(int)
    for x in range(im.shape[0]):
        for y in range(im.shape[1]):
            crop = area[x,y]
            if np.abs(crop-med)>10:
                crop = med
            crop = crop+10
            im[x,y,:crop] = 0

    return im

# %%
cropped = crop_cathode_CL(im)

# %%
plt.imshow(cropped.max(axis=2), 'gray')

# %% [markdown]
# ## Use CL as deliminators and cut a "isosurface" at the center through the membrane
# find peaks, use neighbor position if not found

# %%
import os
import skimage.io
import matplotlib.pyplot as plt

# %%
import matplotlib

# %%
from matplotlib import cm
from matplotlib.colors import Normalize

# %%
import scipy as sp
import scipy.signal

# %%
import numpy as np

# %%
import scipy.ndimage

# %%
im = skimage.io.imread('/mnt/nas_nanotomData/CT_Data_PSI/FR54/2023_COELY_postmortem/D_series/D_1/D_1_postop_2_registered.tif')[100:1100,50:550,:]

# %%
a = 400
b = 370

# %%
def search_crude_CL(im , offset=40):
    med = np.median(im)
    shp = im.shape
    CL = np.zeros((shp[0],shp[1],2), dtype = int)
    grad = -np.gradient(np.gradient(im, axis=2), axis=2)
    # grad = np.gradient(im, axis=2)
    for x in range(shp[0]):
        for y in range(shp[1]):
            prof = grad[x,y,:]
            peaks, props = sp.signal.find_peaks(prof[offset:], height=5.5*med/10, distance=12, prominence=med/4) #gives peaks sorted by height (= ACL first)
            peaks = peaks+offset
            LP = len(peaks)
            if LP>0:
                peaks = peaks[:2]
                CL[x,y,-LP:] = peaks #inverse order to put CCL first
    return CL    #, excess_peaks


def find_center_surface(CL, ser, sample):
    # some hard coded limits and median filtering
    # TODO: consider that position for custom BPM is closer to cathode
    
    CL0 = CL[:,:,0] #CCL ?!
    CL1 = CL[:,:,1] #ACL ?!

    #global median filter
    # medCL0 = np.median(CL0[CL0>0])
    masksmall = CL0<5
    np.random.seed(5) 
    CL0[masksmall] = 5 #np.random.randint(250, size=np.count_nonzero(masksmall))
    

    medCL1 = np.median(CL1)
    # if ser in 'ABCZ':
    CL1[np.abs(CL1-medCL1)>30] = medCL1
    CL0[np.abs(CL0-medCL1)<20] = 5
    
    # print(medCL0, medCL1)

    # #local median filter
    CL0 = sp.ndimage.median_filter(CL0, size = 4)
    CL1 = sp.ndimage.median_filter(CL1, size = 4)
    
    diff = (CL1-CL0)/2
    meddiff = np.median(diff)
    diff[diff<10] = meddiff
    diff[diff>60]  = meddiff
    
    # if ser == 'D' or ser == 'E':
    #     diff[diff<10] = meddiff
    #     diff[diff>95]  = meddiff
    #     IFcoords = np.uint16(CL0+30) #20 roughly the thickness of FAA in px, 30 checks if it can find the Nafiuon membrane
    # else:
    #     IFcoords = np.uint16(CL1-diff)
    
 #   if ser not in 'ABCZ':
#        IFcoords = np.uint16(CL1-62) #58 is a little more than the ANfion thickness

    if ser not in 'ABCZ':
        IFcoords = np.uint16(CL1-65)
        mask = mask = CL0+20>IFcoords
        IFcoords[mask] = np.uint16(CL0[mask]+20)
        coordmed = np.median(IFcoords)
        IFcoords[IFcoords>200] = coordmed
        IFcoords[IFcoords<10] = coordmed
        IFcoords = sp.ndimage.median_filter(IFcoords, size = 4)

        # print(ser, sample, medcoord)
        
    else:
        IFcoords = np.uint16((CL1+CL0)/2)
        coordmed = np.median(IFcoords)
        IFcoords[IFcoords>100] = coordmed
        IFcoords[IFcoords<10] = coordmed
        IFcoords = sp.ndimage.median_filter(IFcoords, size = 4)

    
    return IFcoords

def extract_center_face(im, IFcoords):

    shp = IFcoords.shape
    interface = np.zeros(shp)
    for x in range(shp[0]):
        for y in range(shp[1]):
            z = IFcoords[x,y]
            interface[x,y] = im[x,y,z-4:z+4].min()
            # interface[x,y] = im[x-fs:x+fs,y-fs:y+fs,z-fs:z+fs].mean()  #small mean filtering

    return interface

def cut_through_membrane_center(im, ser, sample):
    CL = search_crude_CL(im)
    IFcoords = find_center_surface(CL, ser, sample)
    interface = extract_center_face(im, IFcoords)
    return interface, IFcoords

# %%
CL = search_crude_CL(im)

# %%
second_it = True
commercial = False
CL0 = CL[:,:,0].copy() #CCL ?!
CL1 = CL[:,:,1].copy() #ACL ?!

#global median filter
medCL0 = np.median(CL0[CL0>0])
masksmall = CL0<1
np.random.seed(5) 
CL0[masksmall] = np.random.randint(medCL0, size=np.count_nonzero(masksmall))
CL0[CL0<5] = 5


medCL1 = np.median(CL1)
CL1[CL1>150] = medCL1
CL1[CL1<50] = medCL1
# if not ser in 'ABCZ':
    # CL1[np.abs(CL1-medCL1)>30] = medCL1

maskextra = np.abs(CL0-medCL1)<22
np.random.seed(5) 
CL0[maskextra] = np.random.randint(medCL0, size=np.count_nonzero(maskextra))

# print(medCL0, medCL1)

# #local median filter
CL0 = sp.ndimage.median_filter(CL0, size = 10)
CL1 = sp.ndimage.median_filter(CL1, size = 10)

# diff = (CL1-CL0)/2
# meddiff = np.median(diff)
# diff[diff<10] = meddiff
# diff[diff>60]  = meddiff

if commercial:
     IFcoords = np.uint16(CL1-65)
     mask = mask = CL0+20>IFcoords
     IFcoords[mask] = np.uint16(CL0[mask]+20)
     coordmed = np.median(IFcoords)
     IFcoords[IFcoords>200] = coordmed
     IFcoords[IFcoords<10] = coordmed
     IFcoords = sp.ndimage.median_filter(IFcoords, size = 10)
 
     # print(ser, sample, medcoord)
     
else:
     IFcoords = np.uint16((CL1+CL0)/2)
     coordmed = np.median(IFcoords)
     IFcoords[IFcoords>80] = coordmed
     IFcoords[IFcoords<30] = coordmed
     IFcoords = sp.ndimage.median_filter(IFcoords, size = 10)


CL1[CL1<coordmed] = medCL1


# second iteration
if second_it:
    #global median filter
    medCL0 = np.median(CL0[CL0>0])
    masksmall = CL0<1
    np.random.seed(5) 
    CL0[masksmall] = np.random.randint(medCL0, size=np.count_nonzero(masksmall))
    CL0[CL0<5] = 5
    
    
    medCL1 = np.median(CL1)
    CL1[CL1>150] = medCL1
    CL1[CL1<50] = medCL1
    # if not ser in 'ABCZ':
        # CL1[np.abs(CL1-medCL1)>30] = medCL1
        
    # print(medCL0, medCL1)
    
    # #local median filter
    CL0 = sp.ndimage.median_filter(CL0, size = 10)
    CL1 = sp.ndimage.median_filter(CL1, size = 10)
    
    # diff = (CL1-CL0)/2
    # meddiff = np.median(diff)
    # diff[diff<10] = meddiff
    # diff[diff>60]  = meddiff
    
    if commercial:
         IFcoords = np.uint16(CL1-65)
         mask = mask = CL0+20>IFcoords
         IFcoords[mask] = np.uint16(CL0[mask]+20)
         coordmed = np.median(IFcoords)
         IFcoords[IFcoords>200] = coordmed
         IFcoords[IFcoords<10] = coordmed
         IFcoords = sp.ndimage.median_filter(IFcoords, size = 10)
     
         # print(ser, sample, medcoord)
         
    else:
         IFcoords = np.uint16((CL1+CL0)/2)
         coordmed = np.median(IFcoords)
         IFcoords[IFcoords>80] = coordmed
         IFcoords[IFcoords<30] = coordmed
     IFcoords = sp.ndimage.median_filter(IFcoords, size = 10)

# %%
# IFcoords = find_center_surface(CL, 'D', '2')

# %%
# interface = extract_center_face(im, IFcoords)

# %%
vmin = -0.0587
vmax = 0.3144*2

# %%
sl = 820
plt.imshow(np.transpose(im[sl,:,:], (1,0)), 'gray', vmin=vmin, vmax=vmax)
plt.plot(CL0[sl,:], 'b')
plt.plot(CL1[sl,:], 'b--')
plt.plot(IFcoords[sl,:], 'r--')
# for ax in axs:
#     ax.axis('off')
#     scalebar = AnchoredSizeBar(ax.transData,
#                        200/3, '200 $\mu m$', 'lower right', 
#                        pad=0.5,
#                        color='black',
#                        frameon=True,
#                        size_vertical=10)
#     ax.add_artist(scalebar)

# %%
b
# Out:
# 370

# %%
plt.plot(-np.gradient(np.gradient(im[a,b,:])))

# %%
test = im[a,b,:].copy()
test = sp.signal.savgol_filter(test, 10, 5)

# %%
peaks, props = sp.signal.find_peaks(-np.gradient(np.gradient(im[a,b,:])), height=0.1, distance=15)

# %%
peaks[:2]
# Out:
# array([37, 66])

# %%
props
# Out:
# {'peak_heights': array([0.57733309, 0.6197108 ])}

# %%
vmin = 10
vmax = 80
cmap = cm.viridis

bounds = np.arange(vmin,vmax, 5)
norm = matplotlib.colors.BoundaryNorm(bounds, cmap.N)

# %%
def search_crude_CL(im):
    med = np.median(im)
    shp = im.shape
    CL = np.zeros((shp[0],shp[1],2), dtype = int)
    grad = -np.gradient(np.gradient(im, axis=2), axis=2)
    # grad = np.gradient(im, axis=2)
    for x in range(shp[0]):
        for y in range(shp[1]):
            prof = grad[x,y,:]
            peaks, props = sp.signal.find_peaks(prof, height=6*med/8, distance=15, prominence=med/4)
            LP = len(peaks)
            if LP>0:
                peaks = peaks[:2]
                CL[x,y,-LP:] = peaks
    return CL    #, excess_peaks

# %%
def find_center_surface(CL):
    # some hard coded limits and median filtering
    
    CL0 = CL[:,:,0]
    CL1 = CL[:,:,1]

    #global median filter
    medCL0 = np.median(CL0[CL0>0])
    CL0[CL0<5] = medCL0

    medCL1 = np.median(CL1)
    CL1[CL1<medCL0+10] = medCL1

    # #local median filter
    CL0 = sp.ndimage.median_filter(CL0, size = 4)
    CL1 = sp.ndimage.median_filter(CL1, size = 4)
    
    diff = (CL1-CL0)/2
    meddiff = np.median(diff)
    diff[diff<10] = meddiff
    diff[diff>60]  = meddiff
    
    IFcoords = np.uint16(CL1-diff)

    # IFcoords = np.uint16((CL1+CL0)/2)
    coordmed = np.median(IFcoords)
    IFcoords[IFcoords>80] = coordmed
    IFcoords[IFcoords<30] = coordmed
    IFcoords = sp.ndimage.median_filter(IFcoords, size = 4)
    
    return IFcoords

def extract_center_face(im, IFcoords):

    shp = IFcoords.shape
    interface = np.zeros(shp)
    for x in range(shp[0]):
        for y in range(shp[1]):
            z = IFcoords[x,y]
            interface[x,y] = im[x,y,z]
            # interface[x,y] = im[x-fs:x+fs,y-fs:y+fs,z-fs:z+fs].mean()  #small mean filtering

    return interface

def cut_through_membrane_center(im):
    CL = search_crude_CL(im)
    IFcoords = find_center_surface(CL)
    interface = extract_center_face(im, IFcoords)
    return interface

# %%
CL = search_crude_CL(im)
IFcoords = find_center_surface(CL)
interface = extract_center_face(im, IFcoords)

# %%
plt.imshow(IFcoords, cmap=cm.viridis, norm=norm)
plt.colorbar()
plt.axis('off')
# Out:
# (-0.5, 499.5, 999.5, -0.5)

# %%
plt.imshow(interface, 'gray', vmin=0, vmax=0.2)
plt.axis('off')
# Out:
# (-0.5, 499.5, 999.5, -0.5)

# %%
plt.imshow(CL[:,:,0])#, cmap=cm.viridis, norm=norm)
plt.colorbar()
plt.axis('off')
# Out:
# (-0.5, 499.5, 999.5, -0.5)

# %%
plt.imshow(CL[:,:,1], cmap=cm.viridis, norm=norm)
plt.colorbar()
plt.axis('off')
# Out:
# (-0.5, 499.5, 999.5, -0.5)

# %%
plt.imshow(CL[:,:,1]-CL[:,:,0], cmap=cm.viridis, norm=norm)
plt.colorbar()
plt.axis('off')
# Out:
# (-0.5, 499.5, 999.5, -0.5)

# %%
plt.imshow((CL[:,:,1]+CL[:,:,0])/2, cmap=cm.viridis, norm=norm)
plt.colorbar()
plt.axis('off')
# Out:
# (-0.5, 499.5, 999.5, -0.5)

# %%
ims = [im1, im2, im3, im4]

# %%
im1 = skimage.io.imread(os.path.join(toppath, 'C_series', 'C_2', 'C_2_postop_1_rotcrop.tif'))

# %%
im2 = skimage.io.imread(os.path.join(toppath, 'C_series', 'C_2', 'C_2_postop_2_rotcrop.tif'))

# %%
im3 = skimage.io.imread(os.path.join(toppath, 'A_series', 'A_12', 'A_12_postop_1_rotcrop.tif'))

# %%
im4 = skimage.io.imread(os.path.join(toppath, 'A_series', 'A_12', 'A_12_postop_2_rotcrop.tif'))

# %%
bins = np.arange(0, 2, 0.01)

# %%
hists = []
for im in ims:
    hist = np.histogram(im.max(axis=2).flatten(), bins=bins)
    hists.append(hist)

# %%
i = 1
for hist in hists:
    plt.plot(bins[1:], hist[0], label=i)
    i = i+1

plt.legend()

# %%
hists = []
for im in ims:
    hist = np.histogram(im.flatten(), bins=bins)
    hists.append(hist)

# %%
i = 1
for hist in hists:
    plt.plot(bins[1:], hist[0], label=i)
    i = i+1

plt.legend()
